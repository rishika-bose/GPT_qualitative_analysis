# %% [markdown]
# # Qualitative Analysis with GPT-3 Embeddings

# %%
import openai
import pandas as pd
import sklearn
import numpy as np
from openai.embeddings_utils import cosine_similarity, get_embedding
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# Setup:

# %%
# Read API key from file:
openai.api_key = open("../openai_key.txt").read()
# Read data from file:
all_dat = pd.read_excel("../data/Changestoself_Analysis_Comments_2_R_2013_12_05.xlsx", sheet_name = "Changestoself_Analysis_Comments")
# Take out comment column for analysis:
#     ASSUMING - demographic data etc. is not being used for coding
comments = all_dat["Comment"]
assert comments.isna().sum() == 0, "There are missing values in comments"
# note - will need to preprocess coding columns for scoring/comparison 

#Model to be used:
MODEL = "text-embedding-ada-002"

# %% [markdown]
# View sample of comments:

# %%
comments.head()
# Out:
# 0     He is already sociable he doesn't need the pill.
# 1    John didn't have a problem - he was just fine ...
# 2    If John was quite comfortable with how social ...
# 3    It seems like he's a pretty well-adjusted guy ...
# 4    John is healthy and is not suffering from any ...
# Name: Comment, dtype: object

# %% [markdown]
# ### Using embeddings
#
#  We can consider this as a classification problem using embeddings. To do this, we can compute similarity between
#  each comment and each code description using embeddings. The codes with similarity above a certain threshold
#  can be considered to be the codes for that comment.
#
#  Referred to descriptions of embeddings and code given here:
#  https://github.com/openai/openai-cookbook/blob/main/examples/Zero-shot_classification_with_embeddings.ipynb

# %% [markdown]
# **Preparation of codes:**

# %% [markdown]
# The qualitative code descriptions being used are shown below. To make them, the three broad categories 'Not comfortable with', 'Comfortable with', and 'Other' were combined with the descriptions for eac sub-category to create a list of descriptions.

# %%
codes = pd.read_excel("../data/Changestoself_Analysis_Comments_2_R_2013_12_05.xlsx", sheet_name = "gpt_codes"
)["Descriptions"]

pd.DataFrame(codes)
# Out:
#                                          Descriptions
# 0      Not comfortable with, no specific reason given
# 1   Not comfortable with, changing something funda...
# 2            Not comfortable with, changing the brain
# 3                   Not comfortable with, side effect
# 4   Not comfortable with, general concerns about p...
# 5   Not comfortable with, No need, nor medically n...
# 6   Not comfortable with, naturalistic moral concerns
# 7   Not comfortable with, risks outweight the bene...
# 8         Not comfortable with, dependence, addiction
# 9     Not comfortable with, social pressure to fit in
# 10          Not comfortable with, legal or prescribed
# 11    Not comfortable with, god or religious concerns
# 12  Not comfortable with, other: fairness, social ...
# 13        Not comfortable with, status quo : new pill
# 14  Not comfortable with, permanent changes (brain...
# 15               Comfortable with, no specific reason
# 16  Comfortable with, not changing anything fundam...
# 17                       Comfortable with, his choice
# 18         Comfortable with, minor or no side effects
# 19  Comfortable with, comfortable with pills and m...
# 20                Comfortable with, positive benefits
# 21  Comfortable with, nothing wrong with using sci...
# 22     Comfortable with, benefits outweight the risks
# 23        Comfortable with, consent/informed decision
# 24           Comfortable with, no pressure to take it
# 25              Comfortable with, legal or prescribed
# 26     Comfortable with, no harm to himself or others
# 27            Comfortable with, other specific reason
# 28      Other, offered a vague or irrelevant response
# 29                         Other, would take the pill
# 30                     Other, would not take the pill

# %% [markdown]
# **Testing with smaller subsection of comments and codes**

# %%
comments_test = [comments[0]]

# %%
codes_test = codes.head()

# %%
from openai.embeddings_utils import cosine_similarity, get_embedding
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
#note: append is deprecated, can be changed later

model = MODEL
df_scores = pd.DataFrame(columns=["Comment", "Code", "Similarity score"])
for m in comments_test:
    comment_embedding = get_embedding(m, engine=model)
    for c in codes:
        code_embedding = get_embedding(c, engine=model)
        score = cosine_similarity(comment_embedding, code_embedding)
        df_scores = df_scores.append(pd.Series({"Comment":m, "Code":c, "Similarity score":score}), ignore_index=True)
        #print("Comment:", m, "Code:", c, "Similarity score:", score)

# %%
df_scores
# Out:
#                                              Comment  \
# 0   He is already sociable he doesn't need the pill.
# 1   He is already sociable he doesn't need the pill.
# 2   He is already sociable he doesn't need the pill.
# 3   He is already sociable he doesn't need the pill.
# 4   He is already sociable he doesn't need the pill.
# 5   He is already sociable he doesn't need the pill.
# 6   He is already sociable he doesn't need the pill.
# 7   He is already sociable he doesn't need the pill.
# 8   He is already sociable he doesn't need the pill.
# 9   He is already sociable he doesn't need the pill.
# 10  He is already sociable he doesn't need the pill.
# 11  He is already sociable he doesn't need the pill.
# 12  He is already sociable he doesn't need the pill.
# 13  He is already sociable he doesn't need the pill.
# 14  He is already sociable he doesn't need the pill.
# 15  He is already sociable he doesn't need the pill.
# 16  He is already sociable he doesn't need the pill.
# 17  He is already sociable he doesn't need the pill.
# 18  He is already sociable he doesn't need the pill.
# 19  He is already sociable he doesn't need the pill.
# 20  He is already sociable he doesn't need the pill.
# 21  He is already sociable he doesn't need the pill.
# 22  He is already sociable he doesn't need the pill.
# 23  He is already sociable he doesn't need the pill.
# 24  He is already sociable he doesn't need the pill.
# 25  He is already sociable he doesn't need the pill.
# 26  He is already sociable he doesn't need the pill.
# 27  He is already sociable he doesn't need the pill.
# 28  He is already sociable he doesn't need the pill.
# 29  He is already sociable he doesn't need the pill.
# 30  He is already sociable he doesn't need the pill.
#
#                                                  Code  Similarity score
# 0      Not comfortable with, no specific reason given          0.753178
# 1   Not comfortable with, changing something funda...          0.738462
# 2            Not comfortable with, changing the brain          0.765766
# 3                   Not comfortable with, side effect          0.774335
# 4   Not comfortable with, general concerns about p...          0.739862
# 5   Not comfortable with, No need, nor medically n...          0.790427
# 6   Not comfortable with, naturalistic moral concerns          0.752322
# 7   Not comfortable with, risks outweight the bene...          0.760949
# 8         Not comfortable with, dependence, addiction          0.783955
# 9     Not comfortable with, social pressure to fit in          0.781162
# 10          Not comfortable with, legal or prescribed          0.760902
# 11    Not comfortable with, god or religious concerns          0.748224
# 12  Not comfortable with, other: fairness, social ...          0.750344
# 13        Not comfortable with, status quo : new pill          0.796549
# 14  Not comfortable with, permanent changes (brain...          0.764145
# 15               Comfortable with, no specific reason          0.776510
# 16  Comfortable with, not changing anything fundam...          0.764428
# 17                       Comfortable with, his choice          0.796965
# 18         Comfortable with, minor or no side effects          0.793100
# 19  Comfortable with, comfortable with pills and m...          0.806734
# 20                Comfortable with, positive benefits          0.793541
# 21  Comfortable with, nothing wrong with using sci...          0.773399
# 22     Comfortable with, benefits outweight the risks          0.795464
# 23        Comfortable with, consent/informed decision          0.761582
# 24           Comfortable with, no pressure to take it          0.811790
# 25              Comfortable with, legal or prescribed          0.766023
# 26     Comfortable with, no harm to himself or others          0.810829
# 27            Comfortable with, other specific reason          0.771753
# 28      Other, offered a vague or irrelevant response          0.730465
# 29                         Other, would take the pill          0.804917
# 30                     Other, would not take the pill          0.807259

# %% [markdown]
# From the above, it appears the similarity scores don't correspond with common sense or the human coding very well.
# This may be due to the code description not being descriptive enough. Below, a more detailed version of the code descriptions are used.

# %%
codes_detailed = pd.read_excel("../data/Changestoself_Analysis_Comments_2_R_2013_12_05.xlsx", sheet_name = "gpt_codes_updated"
)["Descriptions"]

pd.DataFrame(codes_detailed)
# Out:
#                                          Descriptions
# 0   Not comfortable with him taking the pill - no ...
# 1   Not comfortable with him taking the pill - cha...
# 2   Not comfortable with him taking the pill - cha...
# 3   Not comfortable with him taking the pill - sid...
# 4   Not comfortable with him taking the pill - gen...
# 5   Not comfortable with him taking the pill – no ...
# 6   Not comfortable with him taking the pill - nat...
# 7   Not comfortable with him taking the pill - ris...
# 8   Not comfortable with him taking the pill - dep...
# 9   Not comfortable with him taking the pill - soc...
# 10  Not comfortable with him taking the pill - leg...
# 11  Not comfortable with him taking the pill - god...
# 12  Not comfortable with him taking the pill - oth...
# 13  Not comfortable with him taking the pill - sta...
# 14  Not comfortable with him taking the pill - per...
# 15  Comfortable with him taking the pill - no spec...
# 16  Comfortable with him taking the pill - not cha...
# 17  Comfortable with him taking the pill - his choice
# 18  Comfortable with him taking the pill - minor o...
# 19  Comfortable with him taking the pill - comfort...
# 20  Comfortable with him taking the pill - positiv...
# 21  Comfortable with him taking the pill - nothing...
# 22  Comfortable with him taking the pill - benefit...
# 23  Comfortable with him taking the pill - consent...
# 24  Comfortable with him taking the pill - no pres...
# 25  Comfortable with him taking the pill - legal o...
# 26  Comfortable with him taking the pill - no harm...
# 27  Comfortable with him taking the pill - other s...
# 28  Response is vague or irrelevant to comfort lev...
# 29        Response says responder would take the pill
# 30    Response says responder would not take the pill

# %%
#note: append is deprecated, can be changed later

model = MODEL
df_scores_2 = pd.DataFrame(columns=["Comment", "Code", "Similarity score"])
for m in comments_test:
    comment_embedding = get_embedding(m, engine=model)
    for c in codes_detailed:
        code_embedding = get_embedding(c, engine=model)
        score = cosine_similarity(comment_embedding, code_embedding)
        df_scores_2 = df_scores_2.append(pd.Series({"Comment":m, "Code":c, "Similarity score":score}), ignore_index=True)
        #print("Comment:", m, "Code:", c, "Similarity score:", score)

# %%
df_scores_2
# Out:
#                                              Comment  \
# 0   He is already sociable he doesn't need the pill.
# 1   He is already sociable he doesn't need the pill.
# 2   He is already sociable he doesn't need the pill.
# 3   He is already sociable he doesn't need the pill.
# 4   He is already sociable he doesn't need the pill.
# 5   He is already sociable he doesn't need the pill.
# 6   He is already sociable he doesn't need the pill.
# 7   He is already sociable he doesn't need the pill.
# 8   He is already sociable he doesn't need the pill.
# 9   He is already sociable he doesn't need the pill.
# 10  He is already sociable he doesn't need the pill.
# 11  He is already sociable he doesn't need the pill.
# 12  He is already sociable he doesn't need the pill.
# 13  He is already sociable he doesn't need the pill.
# 14  He is already sociable he doesn't need the pill.
# 15  He is already sociable he doesn't need the pill.
# 16  He is already sociable he doesn't need the pill.
# 17  He is already sociable he doesn't need the pill.
# 18  He is already sociable he doesn't need the pill.
# 19  He is already sociable he doesn't need the pill.
# 20  He is already sociable he doesn't need the pill.
# 21  He is already sociable he doesn't need the pill.
# 22  He is already sociable he doesn't need the pill.
# 23  He is already sociable he doesn't need the pill.
# 24  He is already sociable he doesn't need the pill.
# 25  He is already sociable he doesn't need the pill.
# 26  He is already sociable he doesn't need the pill.
# 27  He is already sociable he doesn't need the pill.
# 28  He is already sociable he doesn't need the pill.
# 29  He is already sociable he doesn't need the pill.
# 30  He is already sociable he doesn't need the pill.
#
#                                                  Code  Similarity score
# 0   Not comfortable with him taking the pill - no ...          0.836325
# 1   Not comfortable with him taking the pill - cha...          0.822031
# 2   Not comfortable with him taking the pill - cha...          0.833908
# 3   Not comfortable with him taking the pill - sid...          0.835907
# 4   Not comfortable with him taking the pill - gen...          0.834913
# 5   Not comfortable with him taking the pill – no ...          0.851079
# 6   Not comfortable with him taking the pill - nat...          0.827917
# 7   Not comfortable with him taking the pill - ris...          0.840452
# 8   Not comfortable with him taking the pill - dep...          0.834816
# 9   Not comfortable with him taking the pill - soc...          0.859029
# 10  Not comfortable with him taking the pill - leg...          0.828042
# 11  Not comfortable with him taking the pill - god...          0.824371
# 12  Not comfortable with him taking the pill - oth...          0.823747
# 13  Not comfortable with him taking the pill - sta...          0.839967
# 14  Not comfortable with him taking the pill - per...          0.824934
# 15  Comfortable with him taking the pill - no spec...          0.848619
# 16  Comfortable with him taking the pill - not cha...          0.842575
# 17  Comfortable with him taking the pill - his choice          0.854909
# 18  Comfortable with him taking the pill - minor o...          0.841683
# 19  Comfortable with him taking the pill - comfort...          0.844371
# 20  Comfortable with him taking the pill - positiv...          0.850015
# 21  Comfortable with him taking the pill - nothing...          0.837124
# 22  Comfortable with him taking the pill - benefit...          0.850200
# 23  Comfortable with him taking the pill - consent...          0.826654
# 24  Comfortable with him taking the pill - no pres...          0.860708
# 25  Comfortable with him taking the pill - legal o...          0.836707
# 26  Comfortable with him taking the pill - no harm...          0.856658
# 27  Comfortable with him taking the pill - other s...          0.850533
# 28  Response is vague or irrelevant to comfort lev...          0.784318
# 29        Response says responder would take the pill          0.802644
# 30    Response says responder would not take the pill          0.813928

# %% [markdown]
# This may have improved things a bit, but there are still a lot of false positives (codes with a high score that human coders didn't assign). Another issue here might be that there are two pieces to each code - 'Comfortable/Not comfortable/Other' plus some detail e.g. 'no specific reason/his choice' etc.
# Below, we first ask the model to assign one of the first three labels, and then check which detail has the most similarity.
# As 'Other' doesn't have much meaning by itself, it has been expanded to 'Other than "comfortable with" or "not comfortable with"'.

# %%
codes_separate = pd.read_excel("../data/Changestoself_Analysis_Comments_2_R_2013_12_05.xlsx", sheet_name = "gpt_codes_separate"
)
pd.DataFrame(codes_separate)
# Out:
#                         Not Comfortable with   \
# 0                    no specific reason given
# 1              changing something fundamental
# 2                          changing the brain
# 3                                 side effect
# 4                general concerns about pills
# 5            No need, nor medically necessary
# 6                 naturalistic moral concerns
# 7                risks outweight the benefits
# 8                        dependend,a ddiction
# 9                   social pressure to fit in
# 10                        legal or prescribed
# 11                  god or religious concerns
# 12  other: fairness, social issues, character
# 13                      status quo : new pill
# 14         permanent changes (brain concern?)
#
#                                     Comfortable with   \
# 0                                  no specific reason
# 1                   not changing anything fundamental
# 2                                          his choice
# 3                            minor or no side effects
# 4               comfortable with pills and medication
# 5                                   positive benefits
# 6   nothing wrong with using science or other mean...
# 7                        benefits outweight the risks
# 8                           consent/informed decision
# 9                              no pressure to take it
# 10                                legal or prescribed
# 11                       no harm to himself or others
# 12                              other specific reason
# 13                                                NaN
# 14                                                NaN
#
#                                      Other
# 0   offered a vague or irrelevant response
# 1                      would take the pill
# 2                  would not take the pill
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN

# %%
codes_separate.columns
# Out:
# Index(['Not Comfortable with ', 'Comfortable with ', 'Other'], dtype='object')

# %%
model = MODEL 
comfort_embedding = get_embedding('Comfortable with pill', engine=model)
not_comfort_embedding = get_embedding('Not comfortable with pill', engine=model)
other_embedding = get_embedding('Other than "comfortable with pill" or "not comfortable with pill"', engine=model)

comfort_codes = codes_separate['Comfortable with '].dropna()
not_comfort_codes = codes_separate['Not Comfortable with '].dropna()
other_codes = codes_separate['Other'].dropna()

# %%
df_scores_3 = pd.DataFrame(columns=["Comment", "Comfort", "Code", "Similarity score"])
for m in comments_test:
    comment_embedding = get_embedding(m, engine=model)
    comfort_simil = cosine_similarity(comment_embedding, comfort_embedding)
    not_comfort_simil = cosine_similarity(comment_embedding, not_comfort_embedding)
    other_simil = cosine_similarity(comment_embedding, other_embedding)
    similarities = [comfort_simil, not_comfort_simil, other_simil]
    if (np.argmax(similarities)==0):
        for c in comfort_codes:
            code_embedding = get_embedding(c, engine=model)
            score = cosine_similarity(comment_embedding, code_embedding)
            df_scores_3 = df_scores_3.append(pd.Series({"Comment":m, "Comfort":"Comfortable with",
                                                        "Code":c, "Similarity score":score}), ignore_index=True)
    elif (np.argmax(similarities)==1):
        for c in not_comfort_codes:
            code_embedding = get_embedding(c, engine=model)
            score = cosine_similarity(comment_embedding, code_embedding)
            df_scores_3 = df_scores_3.append(pd.Series({"Comment":m, "Comfort":"Not comfortable with",
                                                        "Code":c, "Similarity score":score}), ignore_index=True)
    elif (np.argmax(similarities)==2):
        for c in other_codes:
            code_embedding = get_embedding(c, engine=model)
            score = cosine_similarity(comment_embedding, code_embedding)
            df_scores_3 = df_scores_3.append(pd.Series({"Comment":m, "Comfort":"Other",
                                                        "Code":c, "Similarity score":score}), ignore_index=True)

# %%
similarities
# Out:
# [0.8280262786083373, 0.8248459645112428, 0.8061247309737856]

# %%
df_scores_3
# Out:
#                                              Comment           Comfort  \
# 0   He is already sociable he doesn't need the pill.  Comfortable with
# 1   He is already sociable he doesn't need the pill.  Comfortable with
# 2   He is already sociable he doesn't need the pill.  Comfortable with
# 3   He is already sociable he doesn't need the pill.  Comfortable with
# 4   He is already sociable he doesn't need the pill.  Comfortable with
# 5   He is already sociable he doesn't need the pill.  Comfortable with
# 6   He is already sociable he doesn't need the pill.  Comfortable with
# 7   He is already sociable he doesn't need the pill.  Comfortable with
# 8   He is already sociable he doesn't need the pill.  Comfortable with
# 9   He is already sociable he doesn't need the pill.  Comfortable with
# 10  He is already sociable he doesn't need the pill.  Comfortable with
# 11  He is already sociable he doesn't need the pill.  Comfortable with
# 12  He is already sociable he doesn't need the pill.  Comfortable with
#
#                                                  Code  Similarity score
# 0                                  no specific reason          0.743782
# 1                   not changing anything fundamental          0.730096
# 2                                          his choice          0.786154
# 3                            minor or no side effects          0.769459
# 4               comfortable with pills and medication          0.816261
# 5                                   positive benefits          0.768501
# 6   nothing wrong with using science or other mean...          0.758062
# 7                        benefits outweight the risks          0.766489
# 8                           consent/informed decision          0.726901
# 9                              no pressure to take it          0.791502
# 10                                legal or prescribed          0.736234
# 11                       no harm to himself or others          0.799848
# 12                              other specific reason          0.731541

# %% [markdown]
# The comment being tested is quite short. Below similarity scores for a longer comment are shown.

# %%
comments_test_long = [comments[4]]
comments_test_long
# Out:
# ['John is healthy and is not suffering from any sort of problem. He is already sociable and it seems odd that he would seek to make himself even more sociable. I would be worried about side effects as well, though ultimately it is up to John to make decisions in his own life.']

# %%
df_scores_4 = pd.DataFrame(columns=["Comment", "Comfort", "Code", "Similarity score"])
for m in comments_test_long:
    comment_embedding = get_embedding(m, engine=model)
    comfort_simil = cosine_similarity(comment_embedding, comfort_embedding)
    not_comfort_simil = cosine_similarity(comment_embedding, not_comfort_embedding)
    other_simil = cosine_similarity(comment_embedding, other_embedding)
    similarities = [comfort_simil, not_comfort_simil, other_simil]
    if (np.argmax(similarities)==0):
        for c in comfort_codes:
            code_embedding = get_embedding(c, engine=model)
            score = cosine_similarity(comment_embedding, code_embedding)
            df_scores_4 = df_scores_4.append(pd.Series({"Comment":m, "Comfort":"Comfortable with",
                                                        "Code":c, "Similarity score":score}), ignore_index=True)
    elif (np.argmax(similarities)==1):
        for c in not_comfort_codes:
            code_embedding = get_embedding(c, engine=model)
            score = cosine_similarity(comment_embedding, code_embedding)
            df_scores_4 = df_scores_4.append(pd.Series({"Comment":m, "Comfort":"Not comfortable with",
                                                        "Code":c, "Similarity score":score}), ignore_index=True)
    elif (np.argmax(similarities)==2):
        for c in other_codes:
            code_embedding = get_embedding(c, engine=model)
            score = cosine_similarity(comment_embedding, code_embedding)
            df_scores_4 = df_scores_4.append(pd.Series({"Comment":m, "Comfort":"Other",
                                                        "Code":c, "Similarity score":score}), ignore_index=True)

# %%
df_scores_4
# Out:
#                                              Comment Comfort  \
# 0  John is healthy and is not suffering from any ...   Other
# 1  John is healthy and is not suffering from any ...   Other
# 2  John is healthy and is not suffering from any ...   Other
#
#                                      Code  Similarity score
# 0  offered a vague or irrelevant response          0.718729
# 1                     would take the pill          0.775010
# 2                 would not take the pill          0.773944

# %% [markdown]
# **Overall conclusion:**
#
# This approach may not be useful to tell between subtle differences in codes. While using embeddings has been useful for sentiment analysis into categories such as 'negative' and 'positive', categories such as 'Comfortable with pill' or 'Not comfortable with pill' may be a bit too subtle to differentiate between just with embeddings.
